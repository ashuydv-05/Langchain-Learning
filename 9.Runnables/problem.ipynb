# %% [markdown]
# Learning Langchain Runnables,

# %%
import random
class NakliLLM:
    def __init__(self):
        print("LLM created")

    def predict(self, prompt):

        response_list = [
            'Delhi is capital of India',
            'IPL is a cricket league',
            'AI stands for Artificial Intelligence'
        ]

        return{'respone': random.choice(response_list)}

# %%
llm = NakliLLM()
# Out:
# LLM created

# %%
llm.predict('what is the capital of India')
# Out:
# {'respone': 'AI stands for Artificial Intelligence'}

# %%
class NakliPromptTemplate:
    def __init__(self, template, input_variable):
        self.template = template
        self.input_variable = input_variable
    
    def format(self, input_dict):
        return self.template.format(**input_dict)

# %%
template = NakliPromptTemplate(
    template = "Write a {length} poem about {topic}",
    input_variable = ['length','topic']
    
)

# %%
prompt =template.format({'length':'short','topic':'india'})

# %%
llm = NakliLLM()
# Out:
# LLM created

# %%
llm.predict(prompt)
# Out:
# {'respone': 'AI stands for Artificial Intelligence'}

# %% [markdown]
# ### Here, we will create an Chain that which directly connect
# prompt and LLM .

# %%
class NakliLLMChain:
    def __init__(self, llm, prompt):
        self.llm = llm
        self.prompt = prompt

    def run(self, input_dict):
        final_prompt = self.prompt.format(input_dict)
        result = self.llm.predict(final_prompt)

        return result['respone']

# %%
template = NakliPromptTemplate(
    template = "Write a {length} poem about {topic}",
    input_variable = ['length','topic']
    
)

# %%
llm = NakliLLM()
# Out:
# LLM created

# %%
chain = NakliLLMChain(llm, template)

# %%
chain.run({'length': 'short','topic': 'india'})
# Out:
# 'IPL is a cricket league'

# %% [markdown]
# ### Cannot Create Multi Stepp chain here, And also not Standarised
